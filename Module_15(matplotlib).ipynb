# %% [markdown]
# <a href="https://colab.research.google.com/github/turon41/Python-for-ML/blob/main/Module_15(matplotlib).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **2D line plot**

# %%
#usage of 2d line plot-->> how a value changes over time, time series data
# EX: business data,temperature data

# %%
hours = [2 , 3 , 4, 1 , 5 , 7 ,3]
days = [1 ,2 , 3 ,4 ,5 ,6 ,7]

plt.plot(days,hours)

# %%
plt.xlabel('Days')
plt.ylabel('Study Hours')
plt.title('Trend of a student study time over a week')

plt.plot(days,hours)

# %%
# for multiple students

hours_1 = [2 , 3 , 4, 1 , 5 , 7 , 3]
hours_2 = [ 1 , 4 , 3 , 5 ,7 ,2 ,1]
days = [1 ,2 , 3 ,4 ,5 ,6 ,7]

plt.xlabel('Days')
plt.ylabel('Study Hours')
plt.title('Trend of a student study time over a week')

plt.plot(days,hours_1)
plt.plot(days,hours_2)

# %% [markdown]
# # **2D line plot from pandas data**

# %%
df = pd.read_csv('enrollment_data(module_15).csv')
df
# Out:
#    Year  Programming  Digital Marketing
# 0  2015          589                734
# 1  2016          862                963
# 2  2017         1085               1157
# 3  2018         1150               1404
# 4  2019         1439               1497
# 5  2020         1715               1579
# 6  2021         1785               1948
# 7  2022         1995               2073
# 8  2023         2236               2310
# 9  2024         2442               2338

# %%
plt.xlabel('Years')
plt.ylabel('Count of Enrollment')
plt.title('Student Enrollment over 8 years')



plt.plot(df['Year'],df['Programming'])

# %%
# for multiple data

plt.xlabel('Years')
plt.ylabel('Count of Enrollment')
plt.title('Student Enrollment over 8 years')



plt.plot(df['Year'],df['Programming'])
plt.plot(df['Year'],df['Digital Marketing'])

# %%
# adding labels using plt.legend()
# for color code google search 'hex color'
# marker -> table onujayi jei jei exact value gula pawa geche tader specify krbe


plt.xlabel('Years')
plt.ylabel('Count of Enrollment')
plt.title('Student Enrollment over 8 years')

plt.plot(df['Year'] ,df['Programming'],label = 'Programming', color ='#11b86f',linewidth=3,linestyle='dashed',marker='o',markersize=7)
plt.plot(df['Year'] ,df['Digital Marketing'], label= 'Digital Marketing', color='black',linewidth=3,linestyle='dashed' )

plt.legend()  # default loc=best
plt.grid()

plt.show()

# %% [markdown]
# # **Scatter Plot**

# %%
students = pd.read_csv('student_IQdata(module_15).csv')
students
# Out:
#     Shoe_Size  Study_Hour  Chilling_Hours  IQ_Score
# 0        13.5         2.0            17.7        72
# 1         8.0        18.0             5.0        75
# 2         6.4         7.2            22.7        78
# 3         6.9         8.7             6.6       110
# 4        10.5         8.6             5.8       104
# 5         6.8         4.8            18.1        76
# 6         5.5         7.9            24.3        80
# 7         9.6        12.6            15.7       109
# 8         9.1         5.6            24.3        73
# 9         6.7        14.6            13.1       110
# 10        9.7        14.2            20.9        98
# 11       10.4        13.7            14.0       109
# 12        7.7        11.9            23.2        95
# 13       12.5         8.3            13.3        95
# 14        7.6         9.4            16.8        95
# 15       11.4         4.6             7.9        96
# 16        5.6        12.2            12.9       107
# 17        8.4        12.3            24.3        87
# 18       12.1         6.4            17.3        77
# 19        6.4         2.7            23.2        70
# 20       13.7         5.4            20.6        78
# 21       13.6         5.3            10.0        87
# 22       18.0        10.0            15.0        98
# 23        6.3         2.2            22.8        70
# 24       11.6         2.4             5.1        90
# 25        5.4         4.9             7.7        89
# 26        9.5         2.0            35.0       145
# 27       10.4        10.6            25.4        86
# 28       13.7        14.8            27.7        88
# 29        8.3         1.6            19.0        70
# 30        6.5         3.0            20.9        70
# 31        5.2        10.3            26.6        86
# 32        7.6         3.7            24.0        70
# 33        8.9        13.5            27.2        77
# 34       10.5        13.9             8.0       116
# 35       12.8         1.5             6.9        93
# 36        6.6         3.6            12.8        84
# 37       10.3         6.0             5.6       102

# %%
#Relation between Study Hours and IQ Score - postive correlation

plt.xlabel('Study Hours')
plt.ylabel('IQ Score')
plt.title('Relation between Study Hours and IQ Score')

plt.scatter(students['Study_Hour'] , students['IQ_Score'])

plt.show()

# %%
#Relation between Shoe size and IQ Score - > no correlation

plt.xlabel('Shoe Size')
plt.ylabel('IQ Score')
plt.title('Relation between Shoe Size and IQ Score')

plt.scatter(students['Shoe_Size'] , students['IQ_Score'])

plt.show()

# %%
#Relation between Chilling hour and IQ Score - > negative correlation

plt.xlabel('Chilling Time')
plt.ylabel('IQ Score')
plt.title('Relation between Chilling hours and IQ Score')

plt.scatter(students['Chilling_Hours'] , students['IQ_Score'],marker='o',color='red')

plt.show()

# %%
# Histogram-> data distributed over a factor, frequency,check outlier

# %% [markdown]
# # **Histogram**

# %%
#based on iq

plt.hist(students['IQ_Score'],color='Red',edgecolor='black')
plt.xlabel('IQ Score')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %%
# based on study hour

plt.hist(students['Study_Hour'],bins=15,color='Red',edgecolor='black')
plt.xlabel('Study Hours')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %%
# bins -> gap for x-axis

plt.hist(students['Study_Hour'],bins=[1,2,3,4,5,6,7,8],color='Red',edgecolor='black')
plt.xlabel('Study Hours')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %%
# Histogram er jnno x-axis e numerical value thke r bar er jnno string value thke

# %% [markdown]
# # **Bar Chart**

# %%
data = {
    'Student': [ 'B', 'C', 'D', 'E', 'F', 'G', 'H'],
    'Gender': [ 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male'],
    'StudyHours': [ 2, 5, 3, 7, 4, 8, 1],
    'Attendance': [ 60, 88, 70, 95, 80, 98, 55],
    'Grade': [ 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#   Student  Gender  StudyHours  Attendance Grade
# 0       B    Male           2          60  Fail
# 1       C  Female           5          88  Pass
# 2       D    Male           3          70  Fail
# 3       E  Female           7          95  Pass
# 4       F    Male           4          80  Pass
# 5       G  Female           8          98  Pass
# 6       H    Male           1          55  Fail

# %%
# gender_wise

gender_group = df.groupby('Gender').size()

gender_group.index
gender_group.values
#gender_group
# Out:
# array([3, 4])

# %%
plt.bar(gender_group.index,gender_group.values,color=['orange','red'],edgecolor='black')

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Bar Chart of Gender among students')
# Out:
# Text(0.5, 1.0, 'Bar Chart of Gender among students')

# %%
#  Bar chart on real data

df = pd.read_csv('student_data.csv')

df
# Out:
#     Unnamed: 0 StudentID          FullName  Data Structure Marks  \
# 0            0    PH1001       Alif Rahman                  85.0
# 1            1    PH1002     Fatima Akhter                  92.0
# 2            2    PH1003     Imran Hossain                  88.0
# 3            3    PH1004  Jannatul Ferdous                  78.0
# 4            4    PH1005       Kamal Uddin                   NaN
# 5            5    PH1006       Laila Begum                  75.0
# 6            6    PH1007    Mahmudul Hasan                  80.0
# 7            7    PH1008       Nadia Islam                  81.0
# 8            8    PH1009        Omar Faruq                  72.0
# 9            9    PH1010      Priya Sharma                  89.0
# 10          10    PH1011      Rahim Sheikh                   NaN
# 11          11    PH1012   Sadia Chowdhury                  85.0
# 12          12    PH1013      Tanvir Ahmed                  75.0
# 13          13    PH1014        Urmi Akter                   NaN
# 14          14    PH1015      Wahiduzzaman                  86.0
# 15          15    PH1016      Ziaur Rahman                  94.0
# 16          16    PH1017       Afsana Mimi                  90.0
# 17          17    PH1018       Babul Ahmed                  88.0
# 18          18    PH1019      Faria Rahman                   NaN
# 19          19    PH1020        Nasir Khan                  86.0
# 20          20       NaN               NaN                   NaN
#
#     Algorithm Marks  Python Marks CompletionStatus EnrollmentDate Instructor  \
# 0              85.0          88.0        Completed      1/15/2024  Mr. Karim
# 1              92.0           NaN      In Progress      1/20/2024  Ms. Salma
# 2              88.0          85.0        Completed      2/10/2024  Mr. Karim
# 3              78.0          82.0        Completed      2/12/2024  Ms. Salma
# 4               NaN          95.0      In Progress       3/5/2024  Mr. Karim
# 5              75.0          78.0        Completed       3/8/2024  Ms. Salma
# 6              80.0           NaN      In Progress       4/1/2024  Mr. Karim
# 7              81.0          85.0        Completed      4/22/2024  Ms. Salma
# 8              72.0          76.0        Completed      5/16/2024  Mr. David
# 9              89.0          88.0        Completed      5/20/2024  Ms. Salma
# 10              NaN          91.0      In Progress      6/11/2024  Mr. Karim
# 11             85.0          87.0        Completed      6/14/2024  Ms. Salma
# 12             75.0          79.0        Completed       7/2/2024  Mr. David
# 13              NaN           NaN      Not Started       7/9/2024  Ms. Salma
# 14             86.0          84.0        Completed      8/18/2024  Mr. Karim
# 15             94.0           NaN      In Progress      8/21/2024  Ms. Salma
# 16             90.0          93.0        Completed       9/1/2025  Mr. Karim
# 17             88.0          85.0        Completed       9/5/2025  Ms. Salma
# 18              NaN           NaN      Not Started      9/15/2025  Mr. David
# 19             86.0          89.0        Completed      10/2/2025  Ms. Salma
# 20              NaN           NaN              NaN            NaN        NaN
#
#       Location
# 0        Dhaka
# 1   Chattogram
# 2        Dhaka
# 3       Sylhet
# 4   Chattogram
# 5     Rajshahi
# 6        Dhaka
# 7   Chattogram
# 8        Dhaka
# 9       Sylhet
# 10      Khulna
# 11  Chattogram
# 12       Dhaka
# 13    Rajshahi
# 14       Dhaka
# 15  Chattogram
# 16       Dhaka
# 17      Sylhet
# 18  Chattogram
# 19       Dhaka
# 20         NaN

# %%
status = df.groupby('CompletionStatus').size()
print(status)
plt.bar(status.index,status.values,color=['green','orange','red'],edgecolor='black')

plt.xlabel('Completion Status')
plt.ylabel('Count')
plt.title('Bar Chart of Course completion')
plt.show()
# Out:
# CompletionStatus
# Completed      13
# In Progress     5
# Not Started     2
# dtype: int64

# %%
# location

status = df.groupby('Location').size()
print(status)

plt.bar(status.index,status.values,edgecolor='black')

plt.xlabel('Location')
plt.ylabel('Count')
plt.title('Bar Chart of Location of Students')
plt.show()
# Out:
# Location
# Chattogram    6
# Dhaka         8
# Khulna        1
# Rajshahi      2
# Sylhet        3
# dtype: int64

# %% [markdown]
# # **pie chart**

# %%
status = df.groupby('CompletionStatus').size()
print(status)

plt.pie(status,labels=status.index,autopct='%1.1f%%')
plt.show()
# Out:
# CompletionStatus
# Completed      13
# In Progress     5
# Not Started     2
# dtype: int64

# %%
status = df.groupby('CompletionStatus').size()
print(status)

plt.pie(status,labels=status.index,autopct='%1.1f%%',explode=[0.1,0,0],shadow =True)
plt.show()
# Out:
# CompletionStatus
# Completed      13
# In Progress     5
# Not Started     2
# dtype: int64
