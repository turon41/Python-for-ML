# %% [markdown]
# <a href="https://colab.research.google.com/github/turon41/Python-for-ML/blob/main/Module_12_5(Practice).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Create a Pandas Series from the list [10, 20, 30, 40, 50]. Print the Series, its index, and data type. Then create a DataFrame with columns "Name", "Age", and "City" containing at least 4 rows of data

# %%
import pandas as pd

data = [10,20,30,40]

series = pd.Series(data)
print(series.dtype)
print(list(series.index))
series
# Out:
# int64
# [0, 1, 2, 3]
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
my_list = {"Name": ["Arafat", "Hasan", "Rafi", "Sadia"],
    "Age": [22, 25, 21, 23],
    "City": ["Dhaka", "Chittagong", "Sylhet", "Rajshahi"]}
df = pd.DataFrame(my_list)
df
# Out:
#      Name  Age        City
# 0  Arafat   22       Dhaka
# 1   Hasan   25  Chittagong
# 2    Rafi   21      Sylhet
# 3   Sadia   23    Rajshahi

# %% [markdown]
# ### 2. Using any DataFrame, write code to print the number of rows and columns, column data types (.dtypes), and summary statistics (.describe())

# %%
my_data = [
    {'Name': 'Alice', 'Age': 25, 'City': 'New York'},
    {'Name': 'Bob', 'Age': 30, 'City': 'Paris'},
    {'Name': 'Charlie', 'Age': 28}
]

data_df = pd.DataFrame(my_data)
data_df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   28       NaN

# %%
# number of rows

import numpy as np
index = np.array(data_df.index)
print(index)
# Out:
# [0 1 2]

# %%
# number of columns

data_df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
# number of rows and columns

print(data_df.shape)

# column data types (.dtypes)
data_df.dtypes
# Out:
# (3, 3)
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
# summary statistics

data_df.describe()
# Out:
#              Age
# count   3.000000
# mean   27.666667
# std     2.516611
# min    25.000000
# 25%    26.500000
# 50%    28.000000
# 75%    29.000000
# max    30.000000

# %% [markdown]
# #### Create a DataFrame using the dictionary below:
#
#
# data = {
#     'Product': ['Pen', 'Book', 'Eraser', 'Pencil'],
#     'Price': [10, 50, 5, 7],
#     'Quantity': [100, 60, 200, 150]
# }
#
# Print .columns, .index. Access a single column and one full row.

# %%
data = { 'Product': ['Pen', 'Book', 'Eraser', 'Pencil'], 'Price': [10, 50, 5, 7], 'Quantity': [100, 60, 200, 150] }
df = pd.DataFrame(data)
print(df.columns)
print(df.index)
print(df['Quantity'])
df.loc[1]
# Out:
# Index(['Product', 'Price', 'Quantity'], dtype='object')
# RangeIndex(start=0, stop=4, step=1)
# 0    100
# 1     60
# 2    200
# 3    150
# Name: Quantity, dtype: int64
# Product     Book
# Price         50
# Quantity      60
# Name: 1, dtype: object

# %% [markdown]
# ### 4. Using .loc[] and .iloc[], show the first row, the second column, and a 2×2 block    from the middle of your DataFrame

# %%
df
# Out:
#   Product  Price  Quantity
# 0     Pen     10       100
# 1    Book     50        60
# 2  Eraser      5       200
# 3  Pencil      7       150

# %%
print(df.loc[0])  # first row
df.iloc[:,1] # second column
# Out:
# Product     Pen
# Price        10
# Quantity    100
# Name: 0, dtype: object
# 0    10
# 1    50
# 2     5
# 3     7
# Name: Price, dtype: int64

# %%
df.iloc[1:3,1:3]   # 2x2 block
# Out:
#    Price  Quantity
# 1     50        60
# 2      5       200

# %% [markdown]
# ### 5. Create a 4×3 DataFrame of student names and marks. Drop one column using .drop(), drop one row by index

# %%
df = pd.DataFrame({
    "Name": ["Arafat", "Hasan", "Rafi", "Sadia"],
    "Math": [85, 78, 92, 88],
    "English": [80, 75, 90, 85]
})

df
# Out:
#      Name  Math  English
# 0  Arafat    85       80
# 1   Hasan    78       75
# 2    Rafi    92       90
# 3   Sadia    88       85

# %%
df.drop(0,inplace=True)   # row deletion
df
# Out:
#     Name  Math  English
# 1  Hasan    78       75
# 2   Rafi    92       90
# 3  Sadia    88       85

# %%
df.drop('Math',axis = 1,inplace = True) # columns deletion
df
# Out:
#     Name  English
# 1  Hasan       75
# 2   Rafi       90
# 3  Sadia       85

# %% [markdown]
# ### 6. Create a DataFrame of employees with columns "Name", "Department", and "Salary". Sort it by "Salary" in ascending order and by "Name" in descending order.

# %%
df = pd.DataFrame({'Name': ['Turon','Tusher','Udoy','Sohan'],
                   'Department': ['Software','Database','Devops','Prompt'],
                   'Salary': [40000,50000,40000,40000]
                   })
df
# Out:
#      Name Department  Salary
# 0   Turon   Software   40000
# 1  Tusher   Database   50000
# 2    Udoy     Devops   40000
# 3   Sohan     Prompt   40000

# %%
df.sort_values(['Salary','Name'],ascending=[1,0]) # eksthe ascending and descending order
# Out:
#      Name Department  Salary
# 2    Udoy     Devops   40000
# 0   Turon   Software   40000
# 3   Sohan     Prompt   40000
# 1  Tusher   Database   50000

# %%
df.sort_values('Salary',ascending=1)
# Out:
#      Name Department  Salary
# 0   Turon   Software   40000
# 2    Udoy     Devops   40000
# 3   Sohan     Prompt   40000
# 1  Tusher   Database   50000

# %%
df.sort_values('Name',ascending=0)
# Out:
#      Name Department  Salary
# 2    Udoy     Devops   40000
# 1  Tusher   Database   50000
# 0   Turon   Software   40000
# 3   Sohan     Prompt   40000

# %% [markdown]
# ### 7.Create a DataFrame of 8 students with columns "Name" and "Score". Filter and print students with Score > 60 and those with Score < 40

# %%
df = pd.DataFrame({
    "Name": ["Arafat", "Hasan", "Rafi", "Sadia", "Lima", "Tuhin", "Nishat", "Kamal"],
    "Score": [75, 55, 82, 33, 60, 28, 92, 45]
})
df
# Out:
#      Name  Score
# 0  Arafat     75
# 1   Hasan     55
# 2    Rafi     82
# 3   Sadia     33
# 4    Lima     60
# 5   Tuhin     28
# 6  Nishat     92
# 7   Kamal     45

# %%
less_score40 = df.loc[df['Score']<40]
less_score40
# Out:
#     Name  Score
# 3  Sadia     33
# 5  Tuhin     28

# %%
gre_score60 = df.loc[df['Score']>60]
gre_score60
# Out:
#      Name  Score
# 0  Arafat     75
# 2    Rafi     82
# 6  Nishat     92
